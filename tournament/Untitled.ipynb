# %%
def tally(rows):
    for row in rows:
        result = split(row,';')
        print (score)

# Program tester
results = ["Allegoric Alaskans;Blithering Badgers;win"]
tally(results)

print ("=> End of program")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d6e1a9d9e038> in <module>
#       6 # Program tester
#       7 results = ["Allegoric Alaskans;Blithering Badgers;win"]
# ----> 8 tally(results)
#       9
#      10 print ("=> End of program")
#
# <ipython-input-1-d6e1a9d9e038> in tally(rows)
#       1 def tally(rows):
#       2     for row in rows:
# ----> 3         result = split(row,';')
#       4         print (score)
#       5
#
# NameError: name 'split' is not defined

# %%
def tally(rows):
    for row in rows:
        result = row.split(';')
        print (score)

# Program tester
results = ["Allegoric Alaskans;Blithering Badgers;win"]
tally(results)

print ("=> End of program")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-75ddd910586b> in <module>
#       6 # Program tester
#       7 results = ["Allegoric Alaskans;Blithering Badgers;win"]
# ----> 8 tally(results)
#       9
#      10 print ("=> End of program")
#
# <ipython-input-2-75ddd910586b> in tally(rows)
#       2     for row in rows:
#       3         result = row.split(';')
# ----> 4         print (score)
#       5
#       6 # Program tester
#
# NameError: name 'score' is not defined

# %%
def tally(rows):
    for row in rows:
        result = row.split(';')
        print (result)

# Program tester
results = ["Allegoric Alaskans;Blithering Badgers;win"]
tally(results)

print ("=> End of program")
# Out:
# ['Allegoric Alaskans', 'Blithering Badgers', 'win']
# => End of program

# %%
def tally(rows):
    rk = dict()
    for row in rows:
        row = row.split(';')
        team1 = rk.get(row[0],[0,0,0,0,0])
        team2 = rk.get(row[1],[0,0,0,0,0])
        result = row[2]
        team1[0] += 1 # +1 MP
        team2[0] += 1 # +1 MP
        if result == "win":
            team1[1] += 1 # +1 Win
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2
    print (rk)

# Program tester
results = ["Allegoric Alaskans;Blithering Badgers;win"]
tally(results)

print ("=> End of program")
# Out:
# {'Allegoric Alaskans': [1, 1, 0, 0, 3], 'Blithering Badgers': [1, 0, 0, 1, 0]}
# => End of program

# %%
def tally(rows):
    rk = dict()
    for row in rows:
        row = row.split(';')
        team1 = rk.get(row[0],[0,0,0,0,0])
        team2 = rk.get(row[1],[0,0,0,0,0])
        result = row[2]
        team1[0] += 1 # +1 MP
        team2[0] += 1 # +1 MP
        if result == "win":
            team1[1] += 1 # +1 Win
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2
    print (rk)

# Program tester
results = [
    "Allegoric Alaskans;Blithering Badgers;win",
    "Allegoric Alaskans;Blithering Badgers;win",
]
tally(results)

print ("=> End of program")
# Out:
# {'Allegoric Alaskans': [2, 2, 0, 0, 6], 'Blithering Badgers': [2, 0, 0, 2, 0]}
# => End of program

# %%
          def tally(rows):
    rk = dict()
    for row in rows:
        row = row.split(';')
        team1 = rk.get(row[0],[0,0,0,0,0])
        team2 = rk.get(row[1],[0,0,0,0,0])
        result = row[2]
        team1[0] += 1 # +1 MP
        team2[0] += 1 # +1 MP
        if result == "win":
            team1[1] += 1 # +1 Win
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2
    print (rk)

# Program tester
results = [
            "Courageous Californians;Devastating Donkeys;win",
            "Allegoric Alaskans;Blithering Badgers;win",
            "Devastating Donkeys;Allegoric Alaskans;loss",
            "Courageous Californians;Blithering Badgers;win",
            "Blithering Badgers;Devastating Donkeys;draw",
            "Allegoric Alaskans;Courageous Californians;draw",
        ]

tally(results)

print ("=> End of program")
# Out:
#   File "<tokenize>", line 11
#     team1[1] += 1 # +1 Win
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
          
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2
    print (rk)

# Program tester
results = [
            "Courageous Californians;Devastating Donkeys;win",
            "Allegoric Alaskans;Blithering Badgers;win",
            "Devastating Donkeys;Allegoric Alaskans;loss",
            "Courageous Californians;Blithering Badgers;win",
            "Blithering Badgers;Devastating Donkeys;draw",
            "Allegoric Alaskans;Courageous Californians;draw",
        ]

tally(results)

print ("=> End of program")
# Out:
#   File "<tokenize>", line 11
#     team1[1] += 1 # +1 Win
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def tally(rows):
    rk = dict()
    for row in rows:
        row = row.split(';')
        team1 = rk.get(row[0],[0,0,0,0,0])
        team2 = rk.get(row[1],[0,0,0,0,0])
        result = row[2]
        team1[0] += 1 # +1 MP
        team2[0] += 1 # +1 MP
        if result == "win":
            team1[1] += 1 # +1 Win
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2
    print (rk)

# Program tester
results = [
            "Courageous Californians;Devastating Donkeys;win",
            "Allegoric Alaskans;Blithering Badgers;win",
            "Devastating Donkeys;Allegoric Alaskans;loss",
            "Courageous Californians;Blithering Badgers;win",
            "Blithering Badgers;Devastating Donkeys;draw",
            "Allegoric Alaskans;Courageous Californians;draw",
        ]

tally(results)

print ("=> End of program")
# Out:
# {'Courageous Californians': [3, 2, 1, 0, 7], 'Devastating Donkeys': [3, 0, 1, 2, 1], 'Allegoric Alaskans': [3, 2, 1, 0, 7], 'Blithering Badgers': [3, 0, 1, 2, 1]}
# => End of program

# %%
def tally(rows):
    rk = dict()
    for row in rows:
        row = row.split(';')
        team1 = rk.get(row[0],[0,0,0,0,0])
        team2 = rk.get(row[1],[0,0,0,0,0])
        result = row[2]
        team1[0] += 1 # +1 MP
        team2[0] += 1 # +1 MP
        if result == "win":
            team1[1] += 1 # +1 Win
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2

    ranking = sorted(rk.items())
    print (ranking)

# Program tester
results = [
            "Courageous Californians;Devastating Donkeys;win",
            "Allegoric Alaskans;Blithering Badgers;win",
            "Devastating Donkeys;Allegoric Alaskans;loss",
            "Courageous Californians;Blithering Badgers;win",
            "Blithering Badgers;Devastating Donkeys;draw",
            "Allegoric Alaskans;Courageous Californians;draw",
        ]

tally(results)

print ("=> End of program")
# Out:
# [('Allegoric Alaskans', [3, 2, 1, 0, 7]), ('Blithering Badgers', [3, 0, 1, 2, 1]), ('Courageous Californians', [3, 2, 1, 0, 7]), ('Devastating Donkeys', [3, 0, 1, 2, 1])]
# => End of program

# %%
def tally(rows):
    rk = dict()
    for row in rows:
        row = row.split(';')
        team1 = rk.get(row[0],[0,0,0,0,0])
        team2 = rk.get(row[1],[0,0,0,0,0])
        result = row[2]
        team1[0] += 1 # +1 MP
        team2[0] += 1 # +1 MP
        if result == "win":
            team1[1] += 1 # +1 Win
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2

    ranking = sorted(rk.items())
    ranking.sort(key = lambda x: x[1][4])
    print (ranking)

# Program tester
results = [
            "Courageous Californians;Devastating Donkeys;win",
            "Allegoric Alaskans;Blithering Badgers;win",
            "Devastating Donkeys;Allegoric Alaskans;loss",
            "Courageous Californians;Blithering Badgers;win",
            "Blithering Badgers;Devastating Donkeys;draw",
            "Allegoric Alaskans;Courageous Californians;draw",
        ]

tally(results)

print ("=> End of program")
# Out:
# [('Blithering Badgers', [3, 0, 1, 2, 1]), ('Devastating Donkeys', [3, 0, 1, 2, 1]), ('Allegoric Alaskans', [3, 2, 1, 0, 7]), ('Courageous Californians', [3, 2, 1, 0, 7])]
# => End of program

# %%
def tally(rows):
    rk = dict()
    for row in rows:
        row = row.split(';')
        team1 = rk.get(row[0],[0,0,0,0,0])
        team2 = rk.get(row[1],[0,0,0,0,0])
        result = row[2]
        team1[0] += 1 # +1 MP
        team2[0] += 1 # +1 MP
        if result == "win":
            team1[1] += 1 # +1 Win
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2

    ranking = sorted(rk.items())
    ranking.sort(reverse = True, key = lambda x: x[1][4])
    print (ranking)

# Program tester
results = [
            "Courageous Californians;Devastating Donkeys;win",
            "Allegoric Alaskans;Blithering Badgers;win",
            "Devastating Donkeys;Allegoric Alaskans;loss",
            "Courageous Californians;Blithering Badgers;win",
            "Blithering Badgers;Devastating Donkeys;draw",
            "Allegoric Alaskans;Courageous Californians;draw",
        ]

tally(results)

print ("=> End of program")
# Out:
# [('Allegoric Alaskans', [3, 2, 1, 0, 7]), ('Courageous Californians', [3, 2, 1, 0, 7]), ('Blithering Badgers', [3, 0, 1, 2, 1]), ('Devastating Donkeys', [3, 0, 1, 2, 1])]
# => End of program

# %%
def tally(rows):
    rk = dict()
    for row in rows:
        row = row.split(';')
        team1 = rk.get(row[0],[0,0,0,0,0])
        team2 = rk.get(row[1],[0,0,0,0,0])
        result = row[2]
        team1[0] += 1 # +1 MP
        team2[0] += 1 # +1 MP
        if result == "win":
            team1[1] += 1 # +1 Win
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2

    ranking = sorted(rk.items())
    ranking.sort(reverse = True, key = lambda x: x[1][4])

    return rkformat(ranking)

def rkformat(ranking):
    tab_ranking = ["Team                           | MP |  W |  D |  L |  P"]
    for rkrow in ranking:
        tab_occur = "{rkrow[0]:<31}|{rkrow[1][0]:>3} |{rkrow[1][1]:>3} |{rkrow[1][2]:>3} |{rkrow[1][3]:>3} |{rkrow[1][4]:>3} |"
        tab_ranking.append(tab_occur)
    return tab_ranking

# Program tester
results = [
            "Courageous Californians;Devastating Donkeys;win",
            "Allegoric Alaskans;Blithering Badgers;win",
            "Devastating Donkeys;Allegoric Alaskans;loss",
            "Courageous Californians;Blithering Badgers;win",
            "Blithering Badgers;Devastating Donkeys;draw",
            "Allegoric Alaskans;Courageous Californians;draw",
        ]

ranking = tally(results)
print (ranking)

print ("=> End of program")
# Out:
# ['Team                           | MP |  W |  D |  L |  P', '{rkrow[0]:<31}|{rkrow[1][0]:>3} |{rkrow[1][1]:>3} |{rkrow[1][2]:>3} |{rkrow[1][3]:>3} |{rkrow[1][4]:>3} |', '{rkrow[0]:<31}|{rkrow[1][0]:>3} |{rkrow[1][1]:>3} |{rkrow[1][2]:>3} |{rkrow[1][3]:>3} |{rkrow[1][4]:>3} |', '{rkrow[0]:<31}|{rkrow[1][0]:>3} |{rkrow[1][1]:>3} |{rkrow[1][2]:>3} |{rkrow[1][3]:>3} |{rkrow[1][4]:>3} |', '{rkrow[0]:<31}|{rkrow[1][0]:>3} |{rkrow[1][1]:>3} |{rkrow[1][2]:>3} |{rkrow[1][3]:>3} |{rkrow[1][4]:>3} |']
# => End of program

# %%
def tally(rows):
    rk = dict()
    for row in rows:
        row = row.split(';')
        team1 = rk.get(row[0],[0,0,0,0,0])
        team2 = rk.get(row[1],[0,0,0,0,0])
        result = row[2]
        team1[0] += 1 # +1 MP
        team2[0] += 1 # +1 MP
        if result == "win":
            team1[1] += 1 # +1 Win
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2

    ranking = sorted(rk.items())
    ranking.sort(reverse = True, key = lambda x: x[1][4])

    return rkformat(ranking)

def rkformat(ranking):
    tab_ranking = ["Team                           | MP |  W |  D |  L |  P"]
    for rkrow in ranking:
        tab_occur = f'{rkrow[0]:<31}|{rkrow[1][0]:>3} |{rkrow[1][1]:>3} |{rkrow[1][2]:>3} |{rkrow[1][3]:>3} |{rkrow[1][4]:>3}'
        tab_ranking.append(tab_occur)
    return tab_ranking

# Program tester
results = [
            "Courageous Californians;Devastating Donkeys;win",
            "Allegoric Alaskans;Blithering Badgers;win",
            "Devastating Donkeys;Allegoric Alaskans;loss",
            "Courageous Californians;Blithering Badgers;win",
            "Blithering Badgers;Devastating Donkeys;draw",
            "Allegoric Alaskans;Courageous Californians;draw",
        ]

ranking = tally(results)
print (ranking)

print ("=> End of program")
# Out:
# ['Team                           | MP |  W |  D |  L |  P', 'Allegoric Alaskans             |  3 |  2 |  1 |  0 |  7', 'Courageous Californians        |  3 |  2 |  1 |  0 |  7', 'Blithering Badgers             |  3 |  0 |  1 |  2 |  1', 'Devastating Donkeys            |  3 |  0 |  1 |  2 |  1']
# => End of program

# %%
def tally(rows):
    rk = dict()
    for row in rows:
        row = row.split(';')
        team1 = rk.get(row[0],[0,0,0,0,0])
        team2 = rk.get(row[1],[0,0,0,0,0])
        result = row[2]
        team1[0] += 1 # +1 MP
        team2[0] += 1 # +1 MP
        if result == "win":
            team1[1] += 1 # +1 Win
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2

    ranking = sorted(rk.items())
    ranking.sort(reverse = True, key = lambda x: x[1][4])

    return rkformat(ranking)

def rkformat(ranking):
    tab_ranking = ["Team                           | MP |  W |  D |  L |  P"]
    print (tab_ranking)
    for rkrow in ranking:
        tab_occur = f'{rkrow[0]:<31}|{rkrow[1][0]:>3} |{rkrow[1][1]:>3} |{rkrow[1][2]:>3} |{rkrow[1][3]:>3} |{rkrow[1][4]:>3}'
        print (tab_occur)
        tab_ranking.append(tab_occur)
    return tab_ranking

# Program tester
results = [
            "Courageous Californians;Devastating Donkeys;win",
            "Allegoric Alaskans;Blithering Badgers;win",
            "Devastating Donkeys;Allegoric Alaskans;loss",
            "Courageous Californians;Blithering Badgers;win",
            "Blithering Badgers;Devastating Donkeys;draw",
            "Allegoric Alaskans;Courageous Californians;draw",
        ]

ranking = tally(results)
print (ranking)

print ("=> End of program")
# Out:
# ['Team                           | MP |  W |  D |  L |  P']
# Allegoric Alaskans             |  3 |  2 |  1 |  0 |  7
# Courageous Californians        |  3 |  2 |  1 |  0 |  7
# Blithering Badgers             |  3 |  0 |  1 |  2 |  1
# Devastating Donkeys            |  3 |  0 |  1 |  2 |  1
# ['Team                           | MP |  W |  D |  L |  P', 'Allegoric Alaskans             |  3 |  2 |  1 |  0 |  7', 'Courageous Californians        |  3 |  2 |  1 |  0 |  7', 'Blithering Badgers             |  3 |  0 |  1 |  2 |  1', 'Devastating Donkeys            |  3 |  0 |  1 |  2 |  1']
# => End of program

# %%
def tally(rows):
    rk = dict()
    for row in rows:
        row = row.split(';')
        team1 = rk.get(row[0],[0,0,0,0,0])
        team2 = rk.get(row[1],[0,0,0,0,0])
        result = row[2]
        team1[0] += 1 # +1 MP
        team2[0] += 1 # +1 MP
        if result == "win":
            team1[1] += 1 # +1 Win
            team1[4] += 3 # +3 points
            team2[3] += 1 # +1 Loss
        elif result == "loss":
            team1[3] += 1 # +1 loss
            team2[1] += 1 # +1 Win
            team2[4] += 3 # +3 points
        else: # Draw
            team1[2] += 1 # +1 draw
            team1[4] += 1 # +1 point
            team2[2] += 1 # +1 draw
            team2[4] += 1 # +1 point
        rk[row[0]] = team1
        rk[row[1]] = team2

    ranking = sorted(rk.items())
    ranking.sort(reverse = True, key = lambda x: x[1][4])

    return rkformat(ranking)

def rkformat(ranking):
    tab_ranking = ["Team                           | MP |  W |  D |  L |  P"]
    print (tab_ranking[0])
    for rkrow in ranking:
        tab_occur = f'{rkrow[0]:<31}|{rkrow[1][0]:>3} |{rkrow[1][1]:>3} |{rkrow[1][2]:>3} |{rkrow[1][3]:>3} |{rkrow[1][4]:>3}'
        print (tab_occur)
        tab_ranking.append(tab_occur)
    return tab_ranking

# Program tester
results = [
            "Courageous Californians;Devastating Donkeys;win",
            "Allegoric Alaskans;Blithering Badgers;win",
            "Devastating Donkeys;Allegoric Alaskans;loss",
            "Courageous Californians;Blithering Badgers;win",
            "Blithering Badgers;Devastating Donkeys;draw",
            "Allegoric Alaskans;Courageous Californians;draw",
        ]

ranking = tally(results)
print (ranking)

print ("=> End of program")
# Out:
# Team                           | MP |  W |  D |  L |  P
# Allegoric Alaskans             |  3 |  2 |  1 |  0 |  7
# Courageous Californians        |  3 |  2 |  1 |  0 |  7
# Blithering Badgers             |  3 |  0 |  1 |  2 |  1
# Devastating Donkeys            |  3 |  0 |  1 |  2 |  1
# ['Team                           | MP |  W |  D |  L |  P', 'Allegoric Alaskans             |  3 |  2 |  1 |  0 |  7', 'Courageous Californians        |  3 |  2 |  1 |  0 |  7', 'Blithering Badgers             |  3 |  0 |  1 |  2 |  1', 'Devastating Donkeys            |  3 |  0 |  1 |  2 |  1']
# => End of program
