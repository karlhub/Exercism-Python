# %%
def latest(scores):
    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    latestSco=scores[lenSco-1]
    return(latestSco)

def personal_best(scores):
    pass

def personal_top_three(scores):
    pass

# Program tester
while True:
    lstScores=input("List Scores: ")
    if lstScores=="done":
         break
    latestScore=latest(lstScores)
    print("Latest Score: ",latestScore)
print("Done!")
# Out:
# List Scores:
# <class 'str'>
# Latest Score:  Empty list
# List Scores: 1
# <class 'str'>
# Latest Score:  1
# List Scores: 12
# <class 'str'>
# Latest Score:  2
# List Scores: 1,3,2,7,9
# <class 'str'>
# Latest Score:  9
# List Scores: 1,4,2,8,34
# <class 'str'>
# Latest Score:  4
# List Scores: (1,4,2,8,34)
# <class 'str'>
# Latest Score:  )
# List Scores: [1,4,2,8,34]
# <class 'str'>
# Latest Score:  ]
# List Scores: done
# Done!

# %%
def latest(scores):
    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    latestSco=scores[lenSco-1]
    return(latestSco)

def personal_best(scores):
    pass

def personal_top_three(scores):
    pass

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        intScore=int(score)
    except:
        print("Not an integer")
    lstScores.append(intScore)

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: a
# Not an integer
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0aad43f6bae0> in <module>
#      27     except:
#      28         print("Not an integer")
# ---> 29     lstScores.append(intScore)
#      30
#      31 latestScore=latest(lstScores)
#
# NameError: name 'intScore' is not defined

# %%
def latest(scores):
    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    latestSco=scores[lenSco-1]
    return(latestSco)

def personal_best(scores):
    pass

def personal_top_three(scores):
    pass

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

print("=> End of program")
# Out:
# Current list:  []
# Enter score:
# Not an integer
# Current list:  []
# Enter score: d
# Not an integer
# Current list:  []
# Enter score: rerererwe
# Not an integer
# Current list:  []
# Enter score: 12
# Current list:  [12]
# Enter score: 13
# Current list:  [12, 13]
# Enter score: 1
# Current list:  [12, 13, 1]
# Enter score: 45
# Current list:  [12, 13, 1, 45]
# Enter score: done
# <class 'list'>
# Latest Score:  45
# => End of program

# %%
def latest(scores):
    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    latestSco=scores[lenSco-1]
    return(latestSco)

def personal_best(scores):
    pass

def personal_top_three(scores):
    pass

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: done
# <class 'list'>
# Latest Score:  Empty list
# => End of program

# %%
def latest(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    latestSco=scores[lenSco-1]
    return(latestSco)

def personal_best(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    bestSco=scores[lenSco-1]
    return(bestSco)

def personal_top_three(scores):
    pass

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

print("=> End of program")
# Out:
# Current list:  []
# Enter score:
# Not an integer
# Current list:  []
# Enter score:
# Not an integer
# Current list:  []
# Enter score:
# Not an integer
# Current list:  []
# Enter score: 1
# Current list:  [1]
# Enter score: 8
# Current list:  [1, 8]
# Enter score: 2
# Current list:  [1, 8, 2]
# Enter score: 9
# Current list:  [1, 8, 2, 9]
# Enter score: 100
# Current list:  [1, 8, 2, 9, 100]
# Enter score: 50
# Current list:  [1, 8, 2, 9, 100, 50]
# Enter score: done
# Latest Score:  50
# Best Score:  100
# => End of program

# %%
def latest(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    latestSco=scores[lenSco-1]
    return(latestSco)

def personal_best(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    bestSco=scores[lenSco-1]
    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    pos=0
    lstTop3=list()
    while True:
        pos+=1
        if pos>lenSco:
            break
        lstTop3.append(scores[lenSco-pos])
    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score:
# Not an integer
# Current list:  []
# Enter score:
# Not an integer
# Current list:  []
# Enter score: done
# Latest Score:  Empty list
# Best Score:  Empty list
# Top 3 Scores:  Empty list
# => End of program

# %%
def latest(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    latestSco=scores[lenSco-1]
    return(latestSco)

def personal_best(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    bestSco=scores[lenSco-1]
    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    pos=0
    lstTop3=list()
    while True:
        pos+=1
        if pos>lenSco:
            break
        lstTop3.append(scores[lenSco-pos])
    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: 5
# Current list:  [5]
# Enter score: 1
# Current list:  [5, 1]
# Enter score: 7
# Current list:  [5, 1, 7]
# Enter score: 34
# Current list:  [5, 1, 7, 34]
# Enter score: 91
# Current list:  [5, 1, 7, 34, 91]
# Enter score: 213
# Current list:  [5, 1, 7, 34, 91, 213]
# Enter score: 43
# Current list:  [5, 1, 7, 34, 91, 213, 43]
# Enter score: 12
# Current list:  [5, 1, 7, 34, 91, 213, 43, 12]
# Enter score: 8
# Current list:  [5, 1, 7, 34, 91, 213, 43, 12, 8]
# Enter score: 77
# Current list:  [5, 1, 7, 34, 91, 213, 43, 12, 8, 77]
# Enter score: done
# Latest Score:  77
# Best Score:  213
# Top 3 Scores:  [213, 91, 77, 43, 34, 12, 8, 7, 5, 1]
# => End of program

# %%
def latest(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    latestSco=scores[lenSco-1]
    return(latestSco)

def personal_best(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    bestSco=scores[lenSco-1]
    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    pos=0
    lstTop3=list()
    while True:
        pos+=1
        if pos>lenSco or pos>3:
            break
        lstTop3.append(scores[lenSco-pos])
    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: 45
# Current list:  [45]
# Enter score: 23
# Current list:  [45, 23]
# Enter score: 6
# Current list:  [45, 23, 6]
# Enter score: 10
# Current list:  [45, 23, 6, 10]
# Enter score: 100
# Current list:  [45, 23, 6, 10, 100]
# Enter score: 74
# Current list:  [45, 23, 6, 10, 100, 74]
# Enter score: 4
# Current list:  [45, 23, 6, 10, 100, 74, 4]
# Enter score: 62
# Current list:  [45, 23, 6, 10, 100, 74, 4, 62]
# Enter score: 22
# Current list:  [45, 23, 6, 10, 100, 74, 4, 62, 22]
# Enter score: 843
# Current list:  [45, 23, 6, 10, 100, 74, 4, 62, 22, 843]
# Enter score: done
# Latest Score:  843
# Best Score:  843
# Top 3 Scores:  [843, 100, 74]
# => End of program

# %%
def latest(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    latestSco=scores[lenSco-1]
    return(latestSco)

def personal_best(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    bestSco=scores[lenSco-1]
    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    pos=0
    lstTop3=list()
    while True:
        pos+=1
        if pos>lenSco or pos>3:
            break
        lstTop3.append(scores[lenSco-pos])
    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: 3
# Current list:  [3]
# Enter score: 100
# Current list:  [3, 100]
# Enter score: 2
# Current list:  [3, 100, 2]
# Enter score: done
# Latest Score:  2
# Best Score:  100
# Top 3 Scores:  [100, 3, 2]
# => End of program

# %%
def latest(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    latestSco=scores[lenSco-1]
    return(latestSco)

def personal_best(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    bestSco=scores[lenSco-1]
    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    pos=0
    lstTop3=list()
    while True:
        pos+=1
        if pos>lenSco or pos>3:
            break
        lstTop3.append(scores[lenSco-pos])
    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: 2
# Current list:  [2]
# Enter score: 22
# Current list:  [2, 22]
# Enter score: done
# Latest Score:  22
# Best Score:  22
# Top 3 Scores:  [22, 2]
# => End of program

# %%
def latest(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    latestSco=scores[lenSco-1]
    return(latestSco)

def personal_best(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    bestSco=scores[lenSco-1]
    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))
    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    scores.sort()
    pos=0
    lstTop3=list()
    while True:
        pos+=1
        if pos>lenSco or pos>3:
            break
        lstTop3.append(scores[lenSco-pos])
    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: 6
# Current list:  [6]
# Enter score: done
# Latest Score:  6
# Best Score:  6
# Top 3 Scores:  [6]
# => End of program
