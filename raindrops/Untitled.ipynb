# %%
def latest(scores):
#    print(type(scores))

    return scores[-1]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    latestSco=scores[lenSco-1]
#    return(latestSco)

def personal_best(scores):
#    print(type(scores))

    return max(scores)

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    bestSco=scores[lenSco-1]
#    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))

    return sorted(scores, reverse=True)[:3]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    pos=0
#    lstTop3=list()
#    while True:
#        pos+=1
#        if pos>lenSco or pos>3:
#            break
#        lstTop3.append(scores[lenSco-pos])
#    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: 4
# Current list:  [4]
# Enter score: 9
# Current list:  [4, 9]
# Enter score: 1
# Current list:  [4, 9, 1]
# Enter score: done
# Latest Score:  1
# Best Score:  9
# Top 3 Scores:  [9, 4, 1]
# => End of program

# %%
def latest(scores):
#    print(type(scores))

    return scores[-1]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    latestSco=scores[lenSco-1]
#    return(latestSco)

def personal_best(scores):
#    print(type(scores))

    return max(scores)

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    bestSco=scores[lenSco-1]
#    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))

    return sorted(scores, reverse=True)[:3]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    pos=0
#    lstTop3=list()
#    while True:
#        pos+=1
#        if pos>lenSco or pos>3:
#            break
#        lstTop3.append(scores[lenSco-pos])
#    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: done
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-84ae2973cfd8> in <module>
#      61         print("Not an integer")
#      62
# ---> 63 latestScore=latest(lstScores)
#      64 print("Latest Score: ",latestScore)
#      65
#
# <ipython-input-2-84ae2973cfd8> in latest(scores)
#       2 #    print(type(scores))
#       3
# ----> 4     return scores[-1]
#       5
#       6 #    try:
#
# IndexError: list index out of range

# %%
def latest(scores):
#    print(type(scores))

    return scores[-1]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    latestSco=scores[lenSco-1]
#    return(latestSco)

def personal_best(scores):
#    print(type(scores))

    return max(scores)

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    bestSco=scores[lenSco-1]
#    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))

    return sorted(scores, reverse=True)[:3]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    pos=0
#    lstTop3=list()
#    while True:
#        pos+=1
#        if pos>lenSco or pos>3:
#            break
#        lstTop3.append(scores[lenSco-pos])
#    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: 1
# Current list:  [1]
# Enter score: done
# Latest Score:  1
# Best Score:  1
# Top 3 Scores:  [1]
# => End of program

# %%
def latest(scores):
#    print(type(scores))

    return scores[-1]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    latestSco=scores[lenSco-1]
#    return(latestSco)

def personal_best(scores):
#    print(type(scores))

    return max(scores)

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    bestSco=scores[lenSco-1]
#    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))

    return sorted(scores, reverse=True)[:3]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    pos=0
#    lstTop3=list()
#    while True:
#        pos+=1
#        if pos>lenSco or pos>3:
#            break
#        lstTop3.append(scores[lenSco-pos])
#    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: 7
# Current list:  [7]
# Enter score: 30
# Current list:  [7, 30]
# Enter score: 41
# Current list:  [7, 30, 41]
# Enter score: done
# Latest Score:  41
# Best Score:  41
# Top 3 Scores:  [41, 30, 7]
# => End of program

# %%
def latest(scores):
#    print(type(scores))

    return scores[-1]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    latestSco=scores[lenSco-1]
#    return(latestSco)

def personal_best(scores):
#    print(type(scores))

    return max(scores)

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    bestSco=scores[lenSco-1]
#    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))

    return sorted(scores, reverse=True)[:3]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    pos=0
#    lstTop3=list()
#    while True:
#        pos+=1
#        if pos>lenSco or pos>3:
#            break
#        lstTop3.append(scores[lenSco-pos])
#    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: 9
# Current list:  [9]
# Enter score: 21
# Current list:  [9, 21]
# Enter score: 7
# Current list:  [9, 21, 7]
# Enter score: 39
# Current list:  [9, 21, 7, 39]
# Enter score: done
# Latest Score:  39
# Best Score:  39
# Top 3 Scores:  [39, 21, 9]
# => End of program

# %%
def latest(scores):
#    print(type(scores))

    return scores[-1]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    latestSco=scores[lenSco-1]
#    return(latestSco)

def personal_best(scores):
#    print(type(scores))

    return max(scores)

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    bestSco=scores[lenSco-1]
#    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))

    return sorted(scores, reverse=True)[:3]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    pos=0
#    lstTop3=list()
#    while True:
#        pos+=1
#        if pos>lenSco or pos>3:
#            break
#        lstTop3.append(scores[lenSco-pos])
#    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

#latestScore=latest(lstScores)
#print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score:
# Not an integer
# Current list:  []
# Enter score: done
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-91c28757e50a> in <module>
#      64 #print("Latest Score: ",latestScore)
#      65
# ---> 66 bestScore=personal_best(lstScores)
#      67 print("Best Score: ",bestScore)
#      68
#
# <ipython-input-6-91c28757e50a> in personal_best(scores)
#      16 #    print(type(scores))
#      17
# ---> 18     return max(scores)
#      19
#      20 #    try:
#
# ValueError: max() arg is an empty sequence

# %%
def latest(scores):
#    print(type(scores))

    return scores[-1]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    latestSco=scores[lenSco-1]
#    return(latestSco)

def personal_best(scores):
#    print(type(scores))

    return max(scores)

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    bestSco=scores[lenSco-1]
#    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))

    return sorted(scores, reverse=True)[:3]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    pos=0
#    lstTop3=list()
#    while True:
#        pos+=1
#        if pos>lenSco or pos>3:
#            break
#        lstTop3.append(scores[lenSco-pos])
#    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

#latestScore=latest(lstScores)
#print("Latest Score: ",latestScore)

#bestScore=personal_best(lstScores)
#print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: done
# Top 3 Scores:  []
# => End of program

# %%
l=[1,2,3,4,5,6,7,8,9]
print("list[2:4]",l[2:4])
print("list[:5]",l[:5])
print("list[1:]",l[1:])
print("list[:]",l[:])
# Out:
# list[2:4] [3, 4]
# list[:5] [1, 2, 3, 4, 5]
# list[1:] [2, 3, 4, 5, 6, 7, 8, 9]
# list[:] [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
max([])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-a48d8f8c12de> in <module>
# ----> 1 max([])
#
# ValueError: max() arg is an empty sequence

# %%
def personal_best(scores):
#    print(type(scores))

    return max(scores)

personal_best(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-dbea0c4f57f5> in <module>
#       4     return max(scores)
#       5
# ----> 6 personal_best(4)
#
# <ipython-input-10-dbea0c4f57f5> in personal_best(scores)
#       2 #    print(type(scores))
#       3
# ----> 4     return max(scores)
#       5
#       6 personal_best(4)
#
# TypeError: 'int' object is not iterable

# %%
def latest(scores):
#    print(type(scores))

    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    return scores[-1]

#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    latestSco=scores[lenSco-1]
#    return(latestSco)

def personal_best(scores):
#    print(type(scores))

    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    if lenSco==0:
        return("Empty list")
    return max(scores)

# Original solution
#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    bestSco=scores[lenSco-1]
#    return(bestSco)

def personal_top_three(scores):
#    print(type(scores))

    try:
        lenSco=len(scores)
    except:
        return("Not a list")
    return sorted(scores, reverse=True)[:3]

# Original solution
#    try:
#        lenSco=len(scores)
#    except:
#        return("Not a list")
#    if lenSco==0:
#        return("Empty list")
#    scores.sort()
#    pos=0
#    lstTop3=list()
#    while True:
#        pos+=1
#        if pos>lenSco or pos>3:
#            break
#        lstTop3.append(scores[lenSco-pos])
#    return(lstTop3)

# Program tester
lstScores=list()
while True:
    print("Current list: ",lstScores)
    score=input("Enter score: ")
    if score=="done":
         break
    try:
        lstScores.append(int(score))
    except:
        print("Not an integer")

latestScore=latest(lstScores)
print("Latest Score: ",latestScore)

bestScore=personal_best(lstScores)
print("Best Score: ",bestScore)

top3Scores=personal_top_three(lstScores)
print("Top 3 Scores: ",top3Scores)

print("=> End of program")
# Out:
# Current list:  []
# Enter score: done
# Latest Score:  Empty list
# Best Score:  Empty list
# Top 3 Scores:  []
# => End of program
